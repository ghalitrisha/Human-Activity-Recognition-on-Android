# %%
import os, sys
import numpy as np
base_path = "/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition"
base_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition'

# %%
wisdm_dataset_path = f'{base_path}/data/WISDM'
wisdm_dataset_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/data/WISDM'

# %%
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import src.load_wisdm_dataset as wisdm

# %%
Xtrain, ytrain, xtest, ytest, labels = wisdm.load_wisdm_dir(wisdm_dataset_path)

# %%
Xtrain.shape, ytrain.shape, xtest.shape, ytest.shape, labels,len(labels)
# Out:
# ((13639, 128, 6),
#  (13639,),
#  (3519, 128, 6),
#  (3519,),
#  ['downstairs', 'jogging', 'sitting', 'standing', 'upstairs', 'walking'],
#  6)

# %%
# !pip install tensorflow-model-optimization
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import src.get_models as models

# %%
import importlib
importlib.reload(models)
# Out:
# <module 'src.get_models' from '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/src/get_models.py'>

# %%
input_shape = Xtrain.shape[1:]
num_classes = len(labels)
input_shape, num_classes
# Out:
# ((128, 6), 6)

# %%
gru_model = models.get_GRU_model(input_shape, num_classes)
# Out:
# 2025-12-15 19:16:24.300623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 19:16:24.301158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
gru_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 128, 6)]          0
#
#  gru_2 (GRU)                 (None, 128, 64)           13824
#
#  gru_3 (GRU)                 (None, 32)                9408
#
#  dense_2 (Dense)             (None, 128)               4224
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 6)                 774
#
# ...
# Total params: 28,742
# Trainable params: 28,486
# Non-trainable params: 256
# _________________________________________________________________

# %%
import keras

# %%
gru_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy'])

# %%
epochs, batch_size = 150, 64

# %%
lr_decay_callback = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                                      patience=8, min_lr=1e-6, verbose=1),
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20)

# %%
gru_model_history = gru_model.fit(Xtrain, ytrain, epochs=epochs, batch_size=batch_size,
                          validation_split=0.1, verbose=1, callbacks=[early_stop, lr_decay_callback])
# Out:
# Epoch 1/150
# 2025-12-15 18:48:24.516658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 18:48:24.518201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
gru_model_history.history['val_accuracy']
# Out:
# [0.7837243676185608,
#  0.7903226017951965,
#  0.8416422009468079,
#  0.8064516186714172,
#  0.8233137726783752,
#  0.7485337257385254,
#  0.8856304883956909,
#  0.8269794583320618,
#  0.8357771039009094,
#  0.8269794583320618,
#  0.8636363744735718,
#  0.8548387289047241,
#  0.8313782811164856,
#  0.8167155385017395,
#  0.8482404947280884,
#  0.8607038259506226,
#  0.8277125954627991,
#  0.8519061803817749,
#  0.8174486756324768,
#  0.8636363744735718,
#  0.8519061803817749,
#  0.8504399061203003,
#  0.8482404947280884,
#  0.8438416719436646,
#  0.8423753380775452,
#  0.8431084752082825,
#  0.8563050031661987]

# %%
gru_model_loss, gru_model_accuracy = gru_model.evaluate(
    xtest, ytest)
# Out:
# 110/110 [==============================] - 1s 13ms/step - loss: 0.7990 - accuracy: 0.8411

# %%
gru_model_accuracy, gru_model_loss
# Out:
# (0.8411480784416199, 0.7990022897720337)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(gru_model_history.history['accuracy'], label='accuracy')
plt.plot(gru_model_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend(loc='lower right')

# %%
gru_model_predict = gru_model.predict(xtest)
gru_model_predict
# Out:
# 2025-12-15 18:53:08.383968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 18:53:08.384842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
y_pred = gru_model_predict.argmax(axis=1)                                     

y_pred_labels = [labels[i] for i in y_pred]
y_pred, y_pred_labels
# Out:
# (array([1, 1, 1, ..., 3, 3, 5]),
#  ['jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'upstairs',
#   'upstairs',
#   'walking',
#   'walking',
#   'walking',
#   'downstairs',
#   'walking',
#   'walking',
#   'downstairs',
#   'upstairs',
#   'upstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'upstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(ytest, y_pred, labels=range(len(labels)))  # raw counts
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

fig, ax = plt.subplots(figsize=(6,5))
disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format="d")
plt.xticks(rotation=45, ha="right")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#   downstairs       0.75      0.76      0.75       339
#      jogging       0.81      0.95      0.87      1041
#      sitting       0.85      0.90      0.87       244
#     standing       1.00      0.96      0.98       210
#     upstairs       0.70      0.73      0.72       380
#      walking       0.93      0.78      0.85      1305
#
#     accuracy                           0.84      3519
#    macro avg       0.84      0.85      0.84      3519
# weighted avg       0.85      0.84      0.84      3519

# %%
gru_model.save(f'{base_path}/models/gru_model_wisdm.keras')

# %%
import tensorflow as tf
run_model = tf.function(lambda x: gru_model(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS = 128
INPUT_SIZE = 6
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE, STEPS, INPUT_SIZE], gru_model.inputs[0].dtype))

# model directory.
MODEL_DIR = f"{base_path}/models_gru_wisdm"
gru_model.save(MODEL_DIR, save_format="tf", signatures=concrete_func)
# Out:
# 2025-12-15 18:55:31.193256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 18:55:31.194295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
float_gru_model = models.get_float_model(MODEL_DIR, f'{base_path}/models/float_gru_wisdm.tflite')
# Out:
# 2025-12-15 18:55:35.131926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 18:55:35.132003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# ...

# %%
def evaluate_model(interpreter):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  prediction_digits = []
  for i, test_image in enumerate(xtest):
    if i % 1000 == 0:
      print('Evaluated on {n} results so far.'.format(n=i))
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
    interpreter.set_tensor(input_index, test_image)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    output = interpreter.tensor(output_index)
    digit = np.argmax(output()[0])
    prediction_digits.append(digit)
#     true_labels = np.argmax(ytest, axis=1)

  print('\n')
  # Compare prediction results with ground truth labels to calculate accuracy.
  prediction_digits = np.array(prediction_digits)
  accuracy = (prediction_digits == ytest).mean()
  return accuracy

# %%
import tensorflow as tf

interpreter_gru_tflite = tf.lite.Interpreter(model_path=f"{base_path}/models/float_gru_wisdm.tflite")
interpreter_gru_tflite.allocate_tensors()

test_accuracy_gru_tflite = evaluate_model(interpreter_gru_tflite)
print("float model accuracy", test_accuracy_gru_tflite)
# Out:
# Evaluated on 0 results so far.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
# Evaluated on 3000 results so far.
#
#
# float model accuracy 0.8411480534242682

# %%
print("GRU Float model WISDM size in MB:", os.path.getsize(f"{base_path}/models/float_gru_wisdm.tflite") / float(2**20))
# Out:
# GRU Float model WISDM size in MB: 0.155303955078125
