# %%
import os, sys
import numpy as np
base_path = "/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition"
base_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition'

# %%
wisdm_dataset_path = f'{base_path}/data/WISDM'
wisdm_dataset_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/data/WISDM'

# %%
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import src.load_wisdm_dataset as wisdm

# %%
import matplotlib.pyplot as plt
def plot_activity_hist(y, labels, title="Training examples by activity type", annotate_pct=True):
    """y: 1D int array of class ids; labels: list of class names in id order."""
    counts = np.bincount(y, minlength=len(labels))
    idx = np.arange(len(labels))

    plt.figure(figsize=(7.5, 4.5))
    plt.bar(idx, counts)
    plt.title(title)
    plt.xticks(idx, labels, rotation=90)
    plt.ylabel("Number of windows")
    plt.tight_layout()

    if annotate_pct:
        total = counts.sum()
        for i, c in enumerate(counts):
            pct = 100.0 * c / total if total else 0.0
            plt.text(i, c, f"{pct:.1f}%", ha="center", va="bottom", fontsize=9)

    plt.show()

# %%
plot_activity_hist(ytrain, labels, title="WISDM train examples by activity")
plot_activity_hist(ytest, labels, title="WISDM test examples by activity")

# %%
Xtrain, ytrain, xtest, ytest, labels = wisdm.load_wisdm_dir(wisdm_dataset_path)

# %%
Xtrain.shape, ytrain.shape, xtest.shape, ytest.shape, labels,len(labels)
# Out:
# ((13639, 128, 6),
#  (13639,),
#  (3519, 128, 6),
#  (3519,),
#  ['downstairs', 'jogging', 'sitting', 'standing', 'upstairs', 'walking'],
#  6)

# %%
# !pip install tensorflow-model-optimization
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import src.get_models as models

# %%
input_shape = Xtrain.shape[1:]
num_classes = len(labels)
input_shape, num_classes
# Out:
# ((128, 6), 6)

# %%
import importlib
importlib.reload(models)
# Out:
# <module 'src.get_models' from '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/src/get_models.py'>

# %%
baseline_model = models.get_baseline_model(input_shape, num_classes)
# Out:
# 2025-12-15 18:38:04.811851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 18:38:04.813038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
baseline_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 128, 6)]          0
#
#  conv1d_2 (Conv1D)           (None, 128, 64)           1984
#
#  batch_normalization_3 (Batc  (None, 128, 64)          256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 128, 64)           0
#
#  conv1d_3 (Conv1D)           (None, 128, 128)          24704
#
#  batch_normalization_4 (Batc  (None, 128, 128)         512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 128, 128)          0
#
#  dropout_1 (Dropout)         (None, 128, 128)          0
#
#  lstm_2 (LSTM)               (None, 128, 128)          131584
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
# ...

# %%
import keras

# %%
baseline_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy'])

# %%
epochs, batch_size = 150, 64

# %%
lr_decay_callback = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                                      patience=8, min_lr=1e-6, verbose=1)
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# %%
baseline_model_history = baseline_model.fit(Xtrain, ytrain, epochs=epochs, batch_size=batch_size,
                          validation_split=0.2, verbose=1, callbacks=[early_stop, lr_decay_callback])
# Out:
# Epoch 1/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.1455 - accuracy: 0.9715 - val_loss: 0.2948 - val_accuracy: 0.9208 - lr: 6.2500e-05
# Epoch 2/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1363 - accuracy: 0.9736 - val_loss: 0.2813 - val_accuracy: 0.9249 - lr: 6.2500e-05
# Epoch 3/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1267 - accuracy: 0.9769 - val_loss: 0.3130 - val_accuracy: 0.9241 - lr: 6.2500e-05
# Epoch 4/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1222 - accuracy: 0.9776 - val_loss: 0.3045 - val_accuracy: 0.9186 - lr: 6.2500e-05
# Epoch 5/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1233 - accuracy: 0.9776 - val_loss: 0.2975 - val_accuracy: 0.9285 - lr: 6.2500e-05
# Epoch 6/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1097 - accuracy: 0.9824 - val_loss: 0.3115 - val_accuracy: 0.9249 - lr: 6.2500e-05
# ...

# %%
baseline_model_loss, baseline_model_accuracy = baseline_model.evaluate(
    xtest, ytest)
# Out:
# 110/110 [==============================] - 3s 25ms/step - loss: 0.8923 - accuracy: 0.8346

# %%
baseline_model_accuracy, baseline_model_loss
# Out:
# (0.8346121311187744, 0.8923198580741882)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(baseline_model_history.history['accuracy'], label='accuracy')
plt.plot(baseline_model_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend(loc='lower right')

# %%
baseline_model_predict = baseline_model.predict(xtest)
baseline_model_predict
# Out:
# 2025-12-15 19:05:16.292158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 19:05:16.292946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
y_pred = baseline_model_predict.argmax(axis=1)                                     

y_pred_labels = [labels[i] for i in y_pred]
y_pred, y_pred_labels
# Out:
# (array([1, 1, 1, ..., 2, 2, 5]),
#  ['jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'jogging',
#   'downstairs',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'walking',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'upstairs',
#   'upstairs',
#   'upstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'upstairs',
#   'upstairs',
#   'upstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
#   'downstairs',
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(ytest, y_pred, labels=range(len(labels)))  # raw counts
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

fig, ax = plt.subplots(figsize=(6,5))
disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format="d")
plt.xticks(rotation=45, ha="right")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
with open(f"{base_path}/results/labels_wisdm.txt", "w") as f:
    for lbl in labels:
        f.write(lbl + "\n")
print("Wrote labels.txt with", len(labels), "labels")
# Out:
# Wrote labels.txt with 6 labels

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#   downstairs       0.85      0.66      0.74       339
#      jogging       0.80      0.92      0.86      1041
#      sitting       0.75      0.89      0.82       244
#     standing       0.97      0.74      0.84       210
#     upstairs       0.65      0.76      0.70       380
#      walking       0.94      0.84      0.88      1305
#
#     accuracy                           0.83      3519
#    macro avg       0.83      0.80      0.81      3519
# weighted avg       0.85      0.83      0.84      3519

# %%
baseline_model.save(f'{base_path}/models/cnn_lstm_wisdm_model.keras')

# %%
import tensorflow as tf
run_model = tf.function(lambda x: baseline_model(x))
BATCH_SIZE = 1
STEPS = 128
INPUT_SIZE = 6
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE, STEPS, INPUT_SIZE], baseline_model.inputs[0].dtype))

# model directory.
MODEL_DIR = f"{base_path}/LSTM_CNN_WISDM"
baseline_model.save(MODEL_DIR, save_format="tf", signatures=concrete_func)
# Out:
# 2025-12-15 19:05:52.202434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 19:05:52.203550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
float_baseline_model = models.get_float_model(MODEL_DIR, f'{base_path}/models/float_lstm_cnn_wisdm.tflite')
# Out:
# 2025-12-15 19:05:58.836486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 19:05:58.836560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# ...

# %%
def evaluate_model(interpreter):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  prediction_digits = []
  for i, test_image in enumerate(xtest):
    if i % 1000 == 0:
      print('Evaluated on {n} results so far.'.format(n=i))
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
    interpreter.set_tensor(input_index, test_image)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    output = interpreter.tensor(output_index)
    digit = np.argmax(output()[0])
    prediction_digits.append(digit)
#     true_labels = np.argmax(ytest, axis=1)

  print('\n')
  # Compare prediction results with ground truth labels to calculate accuracy.
  prediction_digits = np.array(prediction_digits)
  accuracy = (prediction_digits == ytest).mean()
  return accuracy

# %%
import tensorflow as tf

interpreter_lstm_cnn_tflite = tf.lite.Interpreter(model_path=f"{base_path}/models/float_lstm_cnn_wisdm.tflite")
interpreter_lstm_cnn_tflite.allocate_tensors()

test_accuracy_lstm_cnn_tflite = evaluate_model(interpreter_lstm_cnn_tflite)
print("float model accuracy", test_accuracy_lstm_cnn_tflite)
# Out:
# Evaluated on 0 results so far.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
# Evaluated on 3000 results so far.
#
#
# float model accuracy 0.8320545609548167

# %%
print("CNN-LSTM Float model WISDM size in MB:", os.path.getsize(f"{base_path}/models/float_lstm_cnn_wisdm.tflite") / float(2**20))
# Out:
# CNN-LSTM Float model WISDM size in MB: 0.8361968994140625
