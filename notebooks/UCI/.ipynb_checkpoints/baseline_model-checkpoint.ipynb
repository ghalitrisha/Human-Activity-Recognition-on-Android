# %%
import os, sys
import numpy as np
base_path = "/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition"
base_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition'

# %%
uci_har_dataset_path = f'{base_path}/data/UCI_HAR'
uci_har_dataset_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/data/UCI_HAR'

# %%
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import src.load_uci_har_dataset as uci_har

# %%
Xtrain, ytrain, xtest, ytest, labels = uci_har.load_uci_har_dir(uci_har_dataset_path)

# %%
Xtrain.shape, ytrain.shape, xtest.shape, ytest.shape, labels,len(labels)
# Out:
# ((7352, 128, 6),
#  (7352,),
#  (2947, 128, 6),
#  (2947,),
#  ['WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'SITTING',
#   'STANDING',
#   'LAYING'],
#  6)

# %%
import matplotlib.pyplot as plt
def plot_activity_hist(y, labels, title="Training examples by activity type", annotate_pct=True):
    """y: 1D int array of class ids; labels: list of class names in id order."""
    counts = np.bincount(y, minlength=len(labels))
    idx = np.arange(len(labels))

    plt.figure(figsize=(7.5, 4.5))
    plt.bar(idx, counts)
    plt.title(title)
    plt.xticks(idx, labels, rotation=90)
    plt.ylabel("Number of windows")
    plt.tight_layout()

    if annotate_pct:
        total = counts.sum()
        for i, c in enumerate(counts):
            pct = 100.0 * c / total if total else 0.0
            plt.text(i, c, f"{pct:.1f}%", ha="center", va="bottom", fontsize=9)

    plt.show()

# %%
plot_activity_hist(ytrain, labels, title="UCI HAR train examples by activity")
plot_activity_hist(ytest, labels, title="UCI HAR test examples by activity")

# %%
# !pip install tensorflow-model-optimization
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-model-optimization in /s/chopin/k/grad/C837304112/.local/lib/python3.10/site-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/anaconda3/2023.03/lib/python3.10/site-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /s/chopin/k/grad/C837304112/.local/lib/python3.10/site-packages (from tensorflow-model-optimization) (0.1.9)
# Requirement already satisfied: numpy~=1.23 in /usr/local/anaconda3/2023.03/lib/python3.10/site-packages (from tensorflow-model-optimization) (1.23.5)
# Requirement already satisfied: six~=1.14 in /usr/local/anaconda3/2023.03/lib/python3.10/site-packages (from tensorflow-model-optimization) (1.16.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/anaconda3/2023.03/lib/python3.10/site-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (22.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/anaconda3/2023.03/lib/python3.10/site-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (1.14.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import src.get_models as models
# Out:
# 2025-12-15 05:09:58.927717: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-15 05:09:58.929181: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-15 05:09:58.954472: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-15 05:09:58.954974: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-15 05:09:59.610787: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
input_shape = Xtrain.shape[1:]
num_classes = len(labels)
input_shape, num_classes
# Out:
# ((128, 6), 6)

# %%
import importlib
importlib.reload(models)
# Out:
# <module 'src.get_models' from '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/src/get_models.py'>

# %%
baseline_model = models.get_baseline_model(input_shape, num_classes)
# Out:
# 2025-12-15 17:12:26.736951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:26.737535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:26.738112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:12:26.816676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:26.817258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:26.817820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
baseline_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 6)]          0
#
#  conv1d_4 (Conv1D)           (None, 128, 64)           1984
#
#  batch_normalization_6 (Batc  (None, 128, 64)          256
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 128, 64)           0
#
#  conv1d_5 (Conv1D)           (None, 128, 128)          24704
#
#  batch_normalization_7 (Batc  (None, 128, 128)         512
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 128, 128)          0
#
#  dropout_2 (Dropout)         (None, 128, 128)          0
#
#  lstm_4 (LSTM)               (None, 128, 128)          131584
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 218,054
# Trainable params: 217,414
# Non-trainable params: 640
# _________________________________________________________________

# %%
import keras

# %%
baseline_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy'])

# %%
epochs, batch_size = 150, 64

# %%
lr_decay_callback = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                                      patience=8, min_lr=1e-6, verbose=1)
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# %%
baseline_model_history = baseline_model.fit(Xtrain, ytrain, epochs=epochs, batch_size=batch_size,
                          validation_split=0.1, verbose=1, callbacks=[early_stop, lr_decay_callback])
# Out:
# Epoch 1/150
# 2025-12-15 17:12:35.594285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:35.595384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:35.595984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:12:35.672727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:35.673395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:35.673986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:12:36.080183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:36.081152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:36.081792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:12:36.158493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:36.159138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:36.159866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 103/104 [============================>.] - ETA: 0s - loss: 1.0506 - accuracy: 0.5273
# 2025-12-15 17:12:47.954098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:47.954686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:47.955536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:12:48.029161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:12:48.029897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:12:48.030441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 104/104 [==============================] - 14s 117ms/step - loss: 1.0498 - accuracy: 0.5277 - val_loss: 1.9189 - val_accuracy: 0.1698 - lr: 0.0010
# Epoch 2/150
# 104/104 [==============================] - 11s 106ms/step - loss: 0.7943 - accuracy: 0.6176 - val_loss: 1.4312 - val_accuracy: 0.3546 - lr: 0.0010
# Epoch 3/150
# 104/104 [==============================] - 10s 94ms/step - loss: 0.7293 - accuracy: 0.6419 - val_loss: 1.0655 - val_accuracy: 0.5353 - lr: 0.0010
# Epoch 4/150
# 104/104 [==============================] - 8s 80ms/step - loss: 0.6803 - accuracy: 0.6581 - val_loss: 0.6114 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 5/150
# 104/104 [==============================] - 11s 104ms/step - loss: 0.6634 - accuracy: 0.6803 - val_loss: 0.6755 - val_accuracy: 0.6535 - lr: 0.0010
# Epoch 6/150
# 104/104 [==============================] - 11s 106ms/step - loss: 0.6587 - accuracy: 0.6829 - val_loss: 0.5891 - val_accuracy: 0.7106 - lr: 0.0010
# Epoch 7/150
# 104/104 [==============================] - 11s 106ms/step - loss: 0.6686 - accuracy: 0.6708 - val_loss: 0.6624 - val_accuracy: 0.6481 - lr: 0.0010
150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1431 - accuracy: 0.9572 - val_loss: 0.1336 - val_accuracy: 0.9620 - lr: 7.8125e-06
# Epoch 143/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1501 - accuracy: 0.9559 - val_loss: 0.1322 - val_accuracy: 0.9620 - lr: 7.8125e-06
# Epoch 144/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1554 - accuracy: 0.9537 - val_loss: 0.1449 - val_accuracy: 0.9470 - lr: 7.8125e-06
# Epoch 145/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1505 - accuracy: 0.9522 - val_loss: 0.1488 - val_accuracy: 0.9416 - lr: 7.8125e-06
# Epoch 146/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9534
# Epoch 146: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 104/104 [==============================] - 10s 91ms/step - loss: 0.1536 - accuracy: 0.9534 - val_loss: 0.1448 - val_accuracy: 0.9484 - lr: 7.8125e-06
# Epoch 147/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1480 - accuracy: 0.9553 - val_loss: 0.1347 - val_accuracy: 0.9620 - lr: 3.9063e-06
# Epoch 148/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1478 - accuracy: 0.9563 - val_loss: 0.1372 - val_accuracy: 0.9620 - lr: 3.9063e-06
# Epoch 149/150
# 104/104 [==============================] - 10s 93ms/step - loss: 0.1544 - accuracy: 0.9519 - val_loss: 0.1330 - val_accuracy: 0.9620 - lr: 3.9063e-06
# Epoch 150/150
# 104/104 [==============================] - 10s 92ms/step - loss: 0.1462 - accuracy: 0.9544 - val_loss: 0.1253 - val_accuracy: 0.9647 - lr: 3.9063e-06

# %%
baseline_model_loss, baseline_model_accuracy = baseline_model.evaluate(
    xtest, ytest)
# Out:
# 93/93 [==============================] - 3s 29ms/step - loss: 0.2449 - accuracy: 0.9321

# %%
baseline_model_accuracy, baseline_model_loss
# Out:
# (0.9321343898773193, 0.24488027393817902)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(baseline_model_history.history['accuracy'], label='accuracy')
plt.plot(baseline_model_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend(loc='lower right')

# %%
baseline_model_predict = baseline_model.predict(xtest)
baseline_model_predict
# Out:
# 2025-12-15 17:40:53.350734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:40:53.351562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:40:53.352152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:40:53.432169: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:40:53.432784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:40:53.433290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 93/93 [==============================] - 3s 29ms/step
# array([[1.3981864e-04, 8.9096058e-05, 1.0786671e-04, 6.4889491e-02,
#         9.2750454e-01, 7.2690598e-03],
#        [1.5833310e-04, 1.7306357e-04, 1.0404218e-04, 4.6396834e-01,
#         5.2648336e-01, 9.1128098e-03],
#        [3.1747237e-07, 1.6241304e-07, 5.6560765e-07, 1.6331257e-02,
#         9.8365766e-01, 9.9422195e-06],
#        ...,
#        [2.3045131e-06, 9.9999547e-01, 2.0251866e-06, 6.5567434e-08,
#         6.1104032e-08, 3.6599030e-08],
#        [2.9431860e-06, 9.9999452e-01, 2.3026610e-06, 9.0204601e-08,
#         7.8826716e-08, 4.8678068e-08],
#        [2.2719748e-06, 9.9999475e-01, 2.7806973e-06, 7.4075153e-08,
#         6.0807515e-08, 4.0114813e-08]], dtype=float32)

# %%
y_pred = baseline_model_predict.argmax(axis=1)                                     

y_pred_labels = [labels[i] for i in y_pred]
y_pred, y_pred_labels
# Out:
# (array([4, 4, 4, ..., 1, 1, 1]),
#  ['STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'SITTING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'LAYING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'STANDING',
#   'LAYING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'STANDING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'STANDING',
#   'STANDING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING',
#   'WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING',
#   'WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'SITTING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'LAYING',
#   'STANDING',
#   'STANDING',
#   'LAYING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   'WALKING',
#   ...])

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(ytest, y_pred, labels=range(len(labels)))  # raw counts
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

fig, ax = plt.subplots(figsize=(6,5))
disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format="d")
plt.xticks(rotation=45, ha="right")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
with open(f"{base_path}/results/labels.txt", "w") as f:
    for lbl in labels:
        f.write(lbl + "\n")
print("Wrote labels.txt with", len(labels), "labels")
# Out:
# Wrote labels.txt with 6 labels

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, y_pred, target_names=labels))
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.98      0.97      0.97       496
#   WALKING_UPSTAIRS       0.99      0.97      0.98       471
# WALKING_DOWNSTAIRS       0.96      0.99      0.98       420
#            SITTING       0.85      0.91      0.88       491
#           STANDING       0.89      0.95      0.92       532
#             LAYING       0.95      0.82      0.88       537
#
#           accuracy                           0.93      2947
#          macro avg       0.94      0.94      0.93      2947
#       weighted avg       0.93      0.93      0.93      2947

# %%
baseline_model.save(f'{base_path}/models/cnn_lstm_model.keras')

# %%
import tensorflow as tf
run_model = tf.function(lambda x: baseline_model(x))
BATCH_SIZE = 1
STEPS = 128
INPUT_SIZE = 6
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE, STEPS, INPUT_SIZE], baseline_model.inputs[0].dtype))

# model directory.
MODEL_DIR = f"{base_path}/LSTM_CNN"
baseline_model.save(MODEL_DIR, save_format="tf", signatures=concrete_func)
# Out:
# 2025-12-15 17:41:06.859779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:41:06.860556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:41:06.861071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:41:06.942422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:41:06.943078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:41:06.943695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-12-15 17:41:07.062920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:41:07.063850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-12-15 17:41
I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.757804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.757841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:12.794189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.794266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.794302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:12.807019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.807085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.807121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:12.840348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.840423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.840458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:12.895931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.896003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.896037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:12.969603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:12.969673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:12.969708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.045958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.046026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.046061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.062269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.062334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.062367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.074366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.074431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.074465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.090986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.091055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.091089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.115011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.115079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.115113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.151423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.151490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.151527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.217558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.217631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.217665: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.228566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.228628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.228661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.253343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.253412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.253445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.321123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.321194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.321227: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.345645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.345714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.345748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.370640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.370713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.370747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.422470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.422549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.422585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.528512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.528588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.528623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.588209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.588283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.588318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.654966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.655042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.655077: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.682858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:41:13.682933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2025-12-15 17:41:13.682968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2025-12-15 17:41:13.975279: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2025-12-15 17:41:13.975310: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2025-12-15 17:41:13.975991: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/LSTM_CNN
# 2025-12-15 17:41:13.986176: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2025-12-15 17:41:13.986212: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/LSTM_CNN
# 2025-12-15 17:41:14.020483: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2025-12-15 17:41:14.130514: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/LSTM_CNN
# 2025-12-15 17:41:14.195617: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 219626 microseconds.
# 2025-12-15 17:41:14.435865: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2116] Estimated count of arithmetic ops: 6.826 M  ops, equivalently 3.413 M  MACs

# %%
def evaluate_model(interpreter):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  prediction_digits = []
  for i, test_image in enumerate(xtest):
    if i % 1000 == 0:
      print('Evaluated on {n} results so far.'.format(n=i))
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
    interpreter.set_tensor(input_index, test_image)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    output = interpreter.tensor(output_index)
    digit = np.argmax(output()[0])
    prediction_digits.append(digit)
#     true_labels = np.argmax(ytest, axis=1)

  print('\n')
  # Compare prediction results with ground truth labels to calculate accuracy.
  prediction_digits = np.array(prediction_digits)
  accuracy = (prediction_digits == ytest).mean()
  return accuracy

# %%
import tensorflow as tf

interpreter_lstm_cnn_tflite = tf.lite.Interpreter(model_path=f"{base_path}/models/float_lstm_cnn.tflite")
interpreter_lstm_cnn_tflite.allocate_tensors()

test_accuracy_lstm_cnn_tflite = evaluate_model(interpreter_lstm_cnn_tflite)
print("float model accuracy", test_accuracy_lstm_cnn_tflite)
# Out:
# Evaluated on 0 results so far.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
#
#
# float model accuracy 0.8632507634882932

# %%
print("CNN-LSTM Float model size in MB:", os.path.getsize(f"{base_path}/models/float_lstm_cnn.tflite") / float(2**20))
# Out:
# CNN-LSTM Float model size in MB: 0.8361968994140625
