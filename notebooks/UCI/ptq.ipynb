# %%
# !pip install tensorflow-model-optimization
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
# Out:
# 2025-12-15 17:42:37.644122: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-15 17:42:37.645585: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-15 17:42:37.674443: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-15 17:42:37.675052: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
base_path = "/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition"
base_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition'

# %%
uci_har_dataset_path = f'{base_path}/data/UCI_HAR'
uci_har_dataset_path
# Out:
# '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/data/UCI_HAR'

# %%
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import src.load_uci_har_dataset as uci_har

# %%
Xtrain, ytrain, xtest, ytest, labels = uci_har.load_uci_har_dir(uci_har_dataset_path)

# %%
Xtrain.shape, ytrain.shape, xtest.shape, ytest.shape, labels,len(labels)
# Out:
# ((7352, 128, 6),
#  (7352,),
#  (2947, 128, 6),
#  (2947,),
#  ['WALKING',
#   'WALKING_UPSTAIRS',
#   'WALKING_DOWNSTAIRS',
#   'SITTING',
#   'STANDING',
#   'LAYING'],
#  6)

# %%
import src.get_models as models

# %%
input_shape = Xtrain.shape[1:]
num_classes = len(labels)
input_shape, num_classes
# Out:
# ((128, 6), 6)

# %%
import importlib
importlib.reload(models)
# Out:
# <module 'src.get_models' from '/s/chopin/k/grad/C837304112/Documents/ESML/final_project/human_activity_recognition/src/get_models.py'>

# %%
base_model = keras.models.load_model(f'{base_path}/models/cnn_lstm_model.keras')
# Out:
# 2025-12-15 17:43:05.840827: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-15 17:43:05.870117: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ...

# %%
import tensorflow as tf
run_model = tf.function(lambda x: base_model(x))
BATCH_SIZE = 1
STEPS = 128
INPUT_SIZE = 6
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE, STEPS, INPUT_SIZE], base_model.inputs[0].dtype))

# model directory.
MODEL_DIR = f"{base_path}/LSTM_CNN_Dynamic"
base_model.save(MODEL_DIR, save_format="tf", signatures=concrete_func)
# Out:
# 2025-12-15 17:43:13.024298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-12-15 17:43:13.025132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
dynamic_quant_model = models.get_dynamic_quantized_model(MODEL_DIR, f'{base_path}/models/dynamic_lstm_cnn.tflite')
# Out:
# 2025-12-15 17:43:16.843297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:43:16.843394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# ...

# %%
def evaluate_model(interpreter):
    in_det  = interpreter.get_input_details()[0]
    out_det = interpreter.get_output_details()[0]
    in_idx  = in_det["index"]
    out_idx = out_det["index"]
    in_dtype = in_det["dtype"]     
    in_scale, in_zero = in_det["quantization"]
    print("dtype", in_dtype)

    prediction_digits = []
    for i, test_image in enumerate(xtest):
        if i % 1000 == 0:
            print(f"Evaluated on {i} results so far.")

        xi = np.expand_dims(test_image, axis=0).astype(np.float32)

        if in_dtype == np.int8:
            xi_q = np.clip(np.round(xi / in_scale + in_zero), -128, 127).astype(np.int8)
            interpreter.set_tensor(in_idx, xi_q)
        elif in_dtype == np.uint8:
            xi_q = np.round(xi / in_scale + in_zero).astype(np.uint8)
            interpreter.set_tensor(in_idx, xi_q)
        else:
            interpreter.set_tensor(in_idx, xi)

        interpreter.invoke()

        yo = interpreter.get_tensor(out_det["index"])[0]
        prediction_digits.append(int(np.argmax(yo)))

    print('\n')
    prediction_digits = np.array(prediction_digits)
    accuracy = (prediction_digits == ytest).mean()
    return accuracy

# %%
interpreter_dynamic_lstm_cnn_tflite = tf.lite.Interpreter(model_path=f"{base_path}/models/dynamic_lstm_cnn.tflite")
interpreter_dynamic_lstm_cnn_tflite.allocate_tensors()

test_accuracy_dynamic_lstm_cnn_tflite = evaluate_model(interpreter_dynamic_lstm_cnn_tflite)
print("dynamic model accuracy", test_accuracy_dynamic_lstm_cnn_tflite)
# Out:
# dtype <class 'numpy.float32'>
# Evaluated on 0 results so far.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
#
#
# dynamic model accuracy 0.8585001696640652

# %%
print("CNN-LSTM Dynamic model size in MB:", os.path.getsize(f"{base_path}/models/dynamic_lstm_cnn.tflite") / float(2**20))
# Out:
# CNN-LSTM Dynamic model size in MB: 0.224151611328125

# %%
int_quant_model = models.get_int_16x8_quantized_model(MODEL_DIR, Xtrain, f'{base_path}/models/int_lstm_cnn.tflite')
# Out:
# 2025-12-15 17:43:46.082721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2025-12-15 17:43:46.082792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# ...

# %%
interpreter_int_lstm_cnn_tflite = tf.lite.Interpreter(model_path=f"{base_path}/models/int_lstm_cnn.tflite")
interpreter_int_lstm_cnn_tflite.allocate_tensors()

test_accuracy_int_lstm_cnn_tflite = evaluate_model(interpreter_int_lstm_cnn_tflite)
print("int model accuracy", test_accuracy_int_lstm_cnn_tflite)
# Out:
# dtype <class 'numpy.int8'>
# Evaluated on 0 results so far.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
#
#
# int model accuracy 0.8486596538853071

# %%
print("CNN-LSTM Int model size in MB:", os.path.getsize(f"{base_path}/models/int_lstm_cnn.tflite") / float(2**20))
# Out:
# CNN-LSTM Int model size in MB: 0.2248382568359375

# %% [markdown]
# ####
